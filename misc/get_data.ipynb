# %%
import os
from pathlib import Path
import csv

# %%
inp_root = Path('data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104')
out_v1_root = Path('data/networks/RECCSv1_OS1/')
out_v2_root = Path('data/networks/RECCSv2_OS1/')

for network_dir in inp_root.iterdir():
    # Get network id
    network_id = network_dir.name

    for clustering_dir in network_dir.iterdir():
        # Get clustering id
        clustering_id = clustering_dir.name
        if clustering_id in ['0.001', '0.01', '0.1']:
            resolution_id = f'leiden{clustering_id[1:]}'
            clustering_id = 'leiden_cpm_nofiltcm'
        elif clustering_id == 'k10':
            resolution_id = 'k10'
            clustering_id = 'ikc_nofiltcm'
        elif clustering_id == 'mod':
            resolution_id = 'leidenmod'
            clustering_id = 'leiden_mod_nofiltcm'
        elif clustering_id == 'infomap':
            resolution_id = 'infomap'
            clustering_id = 'infomap_nofiltcm'
        else:
            raise ValueError(f'Unknown clustering id: {clustering_id}')

        # Get output directory
        out_v1_dir = out_v1_root / clustering_id / network_id / resolution_id / '0'
        out_v2_dir = out_v2_root / clustering_id / network_id / resolution_id / '0'

        # Create output directory
        out_v1_dir.mkdir(parents=True, exist_ok=True)
        out_v2_dir.mkdir(parents=True, exist_ok=True)

        # Copy files
        os.system(f'cp -r {clustering_dir}/reccsv1_os1.tsv {out_v1_dir}/edge.tsv')
        os.system(f'cp -r {clustering_dir}/reccsv2_os1.tsv {out_v2_dir}/edge.tsv')
# Out:
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/paris_transportation/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/paris_transportation/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/reactome/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/reactome/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dbpedia_writer/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dbpedia_writer/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dblp_coauthor_snap/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dblp_coauthor_snap/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dbpedia_starring/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dbpedia_starring/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/notre_dame_web/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/notre_dame_web/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/chicago_road/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/chicago_road/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dbpedia_team/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dbpedia_team/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dbpedia_country/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dbpedia_country/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/interactome_stelzl/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/interactome_stelzl/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dbpedia_producer/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dbpedia_producer/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/faa_routes/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/faa_routes/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dbpedia_recordlabel/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dbpedia_recordlabel/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dbpedia_genre/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dbpedia_genre/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dbpedia_location/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dbpedia_location/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/power/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/power/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dbpedia_occupation/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/dbpedia_occupation/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/interactome_vidal/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104/interactome_vidal/k10/reccsv2_os1.tsv': No such file or directory

# %%
inp_root = Path('data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104')
out_v1_root = Path('data/networks/RECCSv1_OS1/')
out_v2_root = Path('data/networks/RECCSv2_OS1/')

for network_dir in inp_root.iterdir():
    # Get network id
    network_id = network_dir.name

    for clustering_dir in network_dir.iterdir():
        # Get clustering id
        clustering_id = clustering_dir.name
        if clustering_id in ['0.001', '0.01', '0.1']:
            resolution_id = f'leiden{clustering_id[1:]}'
            clustering_id = 'leiden_cpm'
        elif clustering_id == 'k10':
            resolution_id = 'k10'
            clustering_id = 'ikc_cc'
        elif clustering_id == 'mod':
            resolution_id = 'leidenmod'
            clustering_id = 'leiden_mod'
        elif clustering_id == 'infomap':
            resolution_id = 'infomap'
            clustering_id = 'infomap_cc'
        else:
            raise ValueError(f'Unknown clustering id: {clustering_id}')

        # Get output directory
        out_v1_dir = out_v1_root / clustering_id / network_id / resolution_id / '0'
        out_v2_dir = out_v2_root / clustering_id / network_id / resolution_id / '0'

        # Create output directory
        out_v1_dir.mkdir(parents=True, exist_ok=True)
        out_v2_dir.mkdir(parents=True, exist_ok=True)

        # Copy files
        os.system(f'cp -r {clustering_dir}/reccsv1_os1.tsv {out_v1_dir}/edge.tsv')
        os.system(f'cp -r {clustering_dir}/reccsv2_os1.tsv {out_v2_dir}/edge.tsv')
# Out:
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/paris_transportation/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/paris_transportation/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/dbpedia_writer/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/dbpedia_writer/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/dbpedia_starring/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/dbpedia_starring/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/chicago_road/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/chicago_road/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/dbpedia_team/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/dbpedia_team/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/dbpedia_country/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/dbpedia_country/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/interactome_stelzl/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/interactome_stelzl/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/dbpedia_producer/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/dbpedia_producer/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/faa_routes/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/faa_routes/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/dbpedia_recordlabel/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/dbpedia_recordlabel/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/dbpedia_genre/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/dbpedia_genre/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/dbpedia_location/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/dbpedia_location/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/power/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/power/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/dbpedia_occupation/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/dbpedia_occupation/k10/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/interactome_vidal/k10/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104/interactome_vidal/k10/reccsv2_os1.tsv': No such file or directory

# %%
inp_root = Path('data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104')
out_v1_root = Path('data/networks/RECCSv1_OS1/')
out_v2_root = Path('data/networks/RECCSv2_OS1/')

for network_dir in inp_root.iterdir():
    # Get network id
    network_id = network_dir.name

    for clustering_dir in network_dir.iterdir():
        # Get clustering id
        clustering_id = clustering_dir.name
        if clustering_id in ['sbm', 'sbm_cc', 'sbm_wcc']:
            resolution_id = 'sbm'
        else:
            print(f'Unknown clustering id: {clustering_id}')
            continue

        # Get output directory
        out_v1_dir = out_v1_root / clustering_id / network_id / resolution_id / '0'
        out_v2_dir = out_v2_root / clustering_id / network_id / resolution_id / '0'

        # Create output directory
        out_v1_dir.mkdir(parents=True, exist_ok=True)
        out_v2_dir.mkdir(parents=True, exist_ok=True)

        # Copy files
        os.system(f'cp -r {clustering_dir}/reccsv1_os1.tsv {out_v1_dir}/edge.tsv')
        os.system(f'cp -r {clustering_dir}/reccsv2_os1.tsv {out_v2_dir}/edge.tsv')
# Out:
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/internet_as/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/internet_as/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/wiki_users/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/wiki_users/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/berkstan_web/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/berkstan_web/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/wiki_link_dyn/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/wiki_link_dyn/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/dblp_coauthor_snap/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/dblp_coauthor_snap/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/wordnet/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/wordnet/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/libimseti/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/libimseti/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/marvel_universe/sbm_cc/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/marvel_universe/sbm_cc/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/marvel_universe/sbm_wcc/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/marvel_universe/sbm_wcc/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/jester/sbm_cc/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/jester/sbm_cc/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/jester/sbm_wcc/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/jester/sbm_wcc/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/visualizeus/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/visualizeus/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/wikiconflict/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/wikiconflict/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/plant_pol_robertson/sbm_cc/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/plant_pol_robertson/sbm_cc/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/plant_pol_robertson/sbm_wcc/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/plant_pol_robertson/sbm_wcc/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/google_web/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/google_web/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/dbpedia_team/sbm_cc/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/dbpedia_team/sbm_cc/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/dbpedia_team/sbm_wcc/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/dbpedia_team/sbm_wcc/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/google/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/google/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/hyves/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/hyves/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/email_enron/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/email_enron/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/digg_votes/sbm_cc/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/digg_votes/sbm_cc/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/digg_votes/sbm_wcc/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/digg_votes/sbm_wcc/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/linux/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/linux/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/bitcoin_alpha/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/bitcoin_alpha/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/discogs_label/sbm_cc/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/discogs_label/sbm_cc/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/discogs_label/sbm_wcc/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/discogs_label/sbm_wcc/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/topology/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/topology/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/wiki_article_words/sbm_cc/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/wiki_article_words/sbm_cc/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/wiki_article_words/sbm_wcc/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/wiki_article_words/sbm_wcc/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/dbpedia_location/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/dbpedia_location/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/stanford_web/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/stanford_web/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/epinions/sbm_cc/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/epinions/sbm_cc/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/epinions/sbm_wcc/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/epinions/sbm_wcc/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/epinions/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/epinions/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/dnc/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/dnc/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/academia_edu/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/academia_edu/sbm/reccsv2_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/bibsonomy/sbm/reccsv1_os1.tsv': No such file or directory
# cp: cannot stat 'data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104/bibsonomy/sbm/reccsv2_os1.tsv': No such file or directory

# %%
root = Path('/projects/illinois/eng/cs/chackoge/lanne2/Datasets/clustering/clustered_subnetworks/104_sbm/')
out_root = Path('data/networks/orig/')

for network_dir in root.iterdir():
    if not network_dir.is_dir():
        print(f'{network_dir} is not a directory')
        continue

    network_id = network_dir.name

    cluster_file = network_dir / 'sbm' / 'com_without_o.dat'

    if not cluster_file.exists():
        print(f'{cluster_file} does not exist')
        continue

    out_dir = out_root / 'sbm' / network_id / 'sbm'
    # if out_dir.exists():
    #     print(f'{out_dir} already exists')
    #     continue
    out_dir.mkdir(parents=True, exist_ok=True)

    os.system(f'cp {out_root}/sbm_old/{network_id}/sbm/edge.dat {out_dir}/edge.dat')
    os.system(f'cp {cluster_file} {out_dir}/com.dat')
    os.system(f'cp {out_root}/sbm_old/{network_id}/sbm/source.txt {out_dir}/source.txt')

# %%
root = Path('data/all_empirical_networks_cpp_cc/errors')

for network_dir in root.iterdir():
    if not network_dir.is_dir():
        continue

    log_file = network_dir / 'run_cpp_cc.err'
    if not log_file.exists():
        print(f'No log file for {network_dir}')
        continue

    with open(log_file) as f:
        lines = f.readlines()
        for line in lines:
            if 'Command being timed:' not in line:
                continue

            command = line.strip().split('Command being timed: ')[1]
            args = command.split(' ')
            # Take the argument of the flag '--existing-clustering'
            existing_clustering = args[args.index('--existing-clustering') + 1]
            if 'dwfeng2' not in existing_clustering:
                continue
            if 'degcor' not in existing_clustering:
                continue
            print(f'{network_dir.name}: {existing_clustering}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 root = Path('data/all_empirical_networks_cpp_cc/errors')
# ----> 3 for network_dir in root.iterdir():
#       4     if not network_dir.is_dir():
#       5         continue
#
# File ~/miniconda3/envs/synnet/lib/python3.12/pathlib.py:1056, in Path.iterdir(self)
#    1050 def iterdir(self):
#    1051     """Yield path objects of the directory contents.
#    1052
#    1053     The children are yielded in arbitrary order, and the
#    1054     special entries '.' and '..' are not included.
#    1055     """
# -> 1056     for name in os.listdir(self):
#    1057         yield self._make_child_relpath(name)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/all_empirical_networks_cpp_cc/errors'

# %% [markdown]
# # Get network/clustering

# %%
old_root = '/projects/engrit/illinois-insper/chacko_warnow/sbm_eval/dwfeng2/sbm-membership/'
new_root = 'data/sbm-membership/'

network_root = Path('data/leiden_clustering/110-full-networks')
err_root = Path('data/all_empirical_networks_cpp_cc/errors/')
root = Path('data/sbm-membership/')
output_root = Path('data/networks/orig/sbm')
resolution_id = 'sbm'

for network_dir in err_root.iterdir():
    if not network_dir.is_dir():
        continue

    # Get network id
    network_id = network_dir.name

    # Get network file
    network_fp = network_root / f'{network_id}-clean.tsv'

    log_file = network_dir / 'run_cpp_cc.err'
    if not log_file.exists():
        print(f'No log file for {network_dir}')
        continue

    with open(log_file) as f:
        lines = f.readlines()
        existing_clustering = None
        for line in lines:
            if 'Command being timed:' not in line:
                continue
            else:
                command = line.strip().split('Command being timed: ')[1]
                args = command.split(' ')
                existing_clustering = args[args.index('--existing-clustering') + 1]
                break
        if existing_clustering is None:
            print(f'No existing clustering for {network_dir.name}')
    

    if old_root not in existing_clustering:
        print(f'Not from dwfeng2: {network_dir.name}')
        continue

    existing_clustering_fp = Path(existing_clustering.replace(old_root, new_root))

    # Get clustering file
    clustering_fp = existing_clustering_fp

    #  Get output directory
    output_dir = output_root / network_id / resolution_id

    # Create output directory
    output_dir.mkdir(parents=True, exist_ok=True)

    # Copy files
    os.system(f'cp {clustering_fp} {output_dir}/com.dat')
    os.system(f'cp {network_fp} {output_dir}/edge.dat')

    # Write the source of the clustering
    with open(output_dir / 'source.txt', 'w') as f:
        f.write(existing_clustering)

    # # Read clustering as CSV and write as TSV
    # with open(clustering_fp, 'r') as f:
    #     csv_reader = csv.reader(f, delimiter=' ')
    #     with open(output_dir / 'com.dat', 'w') as f_out:
    #         tsv_writer = csv.writer(f_out, delimiter='\t')
    #         for row in csv_reader:
    #             tsv_writer.writerow(row)
# Out:
# Not from dwfeng2: dblp_author_paper
# Not from dwfeng2: amazon_ratings
# Not from dwfeng2: orkut
# Not from dwfeng2: sp_kenyan_households
# Not from dwfeng2: elite
# Not from dwfeng2: livejournal
# Not from dwfeng2: sa_companies
# Not from dwfeng2: ceo_club
# Not from dwfeng2: macaque_neural
# Not from dwfeng2: cs_department
# Not from dwfeng2: dolphins
# Not from dwfeng2: november17
# Not from dwfeng2: bitcoin
# Not from dwfeng2: dutch_criticism
# Not from dwfeng2: cen
# Not from dwfeng2: contiguous_usa
# Not from dwfeng2: reuters
# Not from dwfeng2: discogs_affiliation

# %%
network_root = Path('data/leiden_clustering/110-full-networks')
root = Path('data/all_empirical_networks_cpp_cc/output')
output_root = Path('data/networks/orig/sbm_cc')
resolution_id = 'sbm'

for network_dir in root.iterdir():
    if not network_dir.is_dir():
        continue

    # Get network id
    network_id = network_dir.name

    # Get network file
    network_fp = network_root / f'{network_id}-clean.tsv'

    # Get clustering file
    clustering_fp = network_dir / 'cpp_cc.clustering'

    #  Get output directory
    output_dir = output_root / network_id / resolution_id

    # Create output directory
    output_dir.mkdir(parents=True, exist_ok=True)

    # Copy files
    # os.system(f'cp {clustering_fp} {output_dir}/com.dat')
    os.system(f'cp {network_fp} {output_dir}/edge.dat')

    # Read clustering as CSV and write as TSV
    with open(clustering_fp, 'r') as f:
        csv_reader = csv.reader(f, delimiter=' ')
        with open(output_dir / 'com.dat', 'w') as f_out:
            tsv_writer = csv.writer(f_out, delimiter='\t')
            for row in csv_reader:
                tsv_writer.writerow(row)
# Out:
# cp: cannot stat 'data/leiden_clustering/110-full-networks/dblp_author_paper-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/amazon_ratings-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/sp_kenyan_households-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/elite-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/livejournal-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/sa_companies-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/ceo_club-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/macaque_neural-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/cs_department-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/dolphins-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/november17-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/bitcoin-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/dutch_criticism-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/contiguous_usa-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/reuters-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/discogs_affiliation-clean.tsv': No such file or directory

# %%
network_root = Path('data/leiden_clustering/110-full-networks')
root = Path('data/all_empirical_networks_cpp_cc/output')
output_root = Path('data/networks/orig/sbm_wcc')
resolution_id = 'sbm'

for network_dir in root.iterdir():
    if not network_dir.is_dir():
        continue

    # Get network id
    network_id = network_dir.name

    # Get network file
    network_fp = network_root / f'{network_id}-clean.tsv'

    # Get clustering file
    clustering_fp = network_dir / 'cpp_wcc.clustering'

    #  Get output directory
    output_dir = output_root / network_id / resolution_id

    # Create output directory
    output_dir.mkdir(parents=True, exist_ok=True)

    # Copy files
    # os.system(f'cp {clustering_fp} {output_dir}/com.dat')
    os.system(f'cp {network_fp} {output_dir}/edge.dat')

    # Read clustering as CSV and write as TSV
    if not clustering_fp.exists():
        print(f'Clustering file does not exist: {clustering_fp}')
        continue
    
    with open(clustering_fp, 'r') as f:
        csv_reader = csv.reader(f, delimiter=' ')
        with open(output_dir / 'com.dat', 'w') as f_out:
            tsv_writer = csv.writer(f_out, delimiter='\t')
            for row in csv_reader:
                tsv_writer.writerow(row)
# Out:
# cp: cannot stat 'data/leiden_clustering/110-full-networks/dblp_author_paper-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/amazon_ratings-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/sp_kenyan_households-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/elite-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/livejournal-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/sa_companies-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/ceo_club-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/macaque_neural-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/cs_department-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/dolphins-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/november17-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/bitcoin-clean.tsv': No such file or directory
# Clustering file does not exist: data/all_empirical_networks_cpp_cc/output/bitcoin/cpp_wcc.clustering
# cp: cannot stat 'data/leiden_clustering/110-full-networks/dutch_criticism-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/contiguous_usa-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/reuters-clean.tsv': No such file or directory
# cp: cannot stat 'data/leiden_clustering/110-full-networks/discogs_affiliation-clean.tsv': No such file or directory

# %%
# network_root = Path('data/leiden_clustering/110-full-networks')
# root = Path('data/leiden_clustering/110-networks-cm-no-filtering/cc-clustering')
# output_root = Path('data/networks/orig/')

# %%
# for S in root.iterdir():
#     # Process S2 only
#     if S.name != 'S2':
#         continue

#     for network_dir in S.iterdir():
#         # Get network id
#         network_id = network_dir.name

#         # Get network file
#         network_fp = network_root / f'{network_id}-clean.tsv'

#         for clustering_dir in network_dir.iterdir():
#             # Get clustering id
#             clustering_id = clustering_dir.name
#             if clustering_id in ['0.001', '0.01', '0.1']:
#                 resolution_id = f'leiden{clustering_id[1:]}'
#                 clustering_id = 'leiden_cpm'
#             elif clustering_id == 'k10':
#                 resolution_id = 'k10'
#                 clustering_id = 'ikc_cc'
#             elif clustering_id == 'mod':
#                 resolution_id = 'leidenmod'
#                 clustering_id = 'leiden_mod'
#             elif clustering_id == 'infomap':
#                 resolution_id = 'infomap'
#                 clustering_id = 'infomap_cc'
#             else:
#                 raise ValueError(f'Unknown clustering id: {clustering_id}')

#             # Get clustering file
#             clustering_fp = clustering_dir / 'cc' / 'com.tsv'

#             # Get output directory
#             output_dir = output_root / clustering_id / network_id / resolution_id

#             # Create output directory
#             output_dir.mkdir(parents=True, exist_ok=True)

#             # Copy files
#             os.system(f'cp {clustering_fp} {output_dir}/com.dat')
#             os.system(f'cp {network_fp} {output_dir}/edge.dat')

# %%
# for S in root.iterdir():
#     if S.name != 'S4':
#         continue
    
#     for network_dir in S.iterdir():
#         # Get network id
#         network_id = network_dir.name

#         # Get network file
#         network_fp = network_root / f'{network_id}-clean.tsv'

#         for clustering_dir in network_dir.iterdir():
#             # Get clustering id
#             clustering_id = clustering_dir.name
#             if clustering_id in ['0.001', '0.01', '0.1']:
#                 resolution_id = f'leiden{clustering_id[1:]}'
#                 clustering_id = 'leiden_cpm_nofiltcm'
#             elif clustering_id == 'k10':
#                 resolution_id = 'k10'
#                 clustering_id = 'ikc_nofiltcm'
#             elif clustering_id == 'mod':
#                 resolution_id = 'leidenmod'
#                 clustering_id = 'leiden_mod_nofiltcm'
#             elif clustering_id == 'infomap':
#                 resolution_id = 'infomap'
#                 clustering_id = 'infomap_nofiltcm'
#             else:
#                 raise ValueError(f'Unknown clustering id: {clustering_id}')

#             # Get clustering file
#             clustering_fp = clustering_dir / 'com.tsv'

#             # Get output directory
#             output_dir = output_root / clustering_id / network_id / resolution_id

#             # Create output directory
#             output_dir.mkdir(parents=True, exist_ok=True)

#             # Copy files
#             os.system(f'cp {clustering_fp} {output_dir}/com.dat')
#             os.system(f'cp {network_fp} {output_dir}/edge.dat')

# %% [markdown]
# # Get statistics

# %%
inp_root = Path('data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104_Evaluation/RECCSv1/OS1')
out_root = Path('data/stats/RECCSv1_OS1/')

for network_dir in inp_root.iterdir():
    # Get network id
    network_id = network_dir.name

    for clustering_dir in network_dir.iterdir():
        # Get clustering id
        clustering_id = clustering_dir.name
        if clustering_id in ['0.001', '0.01', '0.1']:
            resolution_id = f'leiden{clustering_id[1:]}'
            clustering_id = 'leiden_cpm_nofiltcm'
        elif clustering_id == 'k10':
            resolution_id = 'k10'
            clustering_id = 'ikc_nofiltcm'
        elif clustering_id == 'mod':
            resolution_id = 'leidenmod'
            clustering_id = 'leiden_mod_nofiltcm'
        elif clustering_id == 'infomap':
            resolution_id = 'infomap'
            clustering_id = 'infomap_nofiltcm'
        elif clustering_id in ['sbm', 'sbm_cc', 'sbm_wcc']:
            resolution_id = 'sbm'
        else:
            raise ValueError(f'Unknown clustering id: {clustering_id}')

        # Get output directory
        output_dir = out_root / clustering_id / network_id / resolution_id

        # Create output directory
        output_dir.mkdir(parents=True, exist_ok=True)

        # Copy files
        os.system(f'cp -r {clustering_dir} {output_dir}/0/')

# %%
inp_root = Path('data/SBM_FullNetworks/FullNetwork_RECCS_OS1_SBM_104_Evaluation/RECCSv2/OS1')
out_root = Path('data/stats/RECCSv2_OS1/')

for network_dir in inp_root.iterdir():
    # Get network id
    network_id = network_dir.name

    for clustering_dir in network_dir.iterdir():
        # Get clustering id
        clustering_id = clustering_dir.name
        if clustering_id in ['0.001', '0.01', '0.1']:
            resolution_id = f'leiden{clustering_id[1:]}'
            clustering_id = 'leiden_cpm_nofiltcm'
        elif clustering_id == 'k10':
            resolution_id = 'k10'
            clustering_id = 'ikc_nofiltcm'
        elif clustering_id == 'mod':
            resolution_id = 'leidenmod'
            clustering_id = 'leiden_mod_nofiltcm'
        elif clustering_id == 'infomap':
            resolution_id = 'infomap'
            clustering_id = 'infomap_nofiltcm'
        elif clustering_id in ['sbm', 'sbm_cc', 'sbm_wcc']:
            resolution_id = 'sbm'
        else:
            raise ValueError(f'Unknown clustering id: {clustering_id}')

        # Get output directory
        output_dir = out_root / clustering_id / network_id / resolution_id

        # Create output directory
        output_dir.mkdir(parents=True, exist_ok=True)

        # Copy files
        os.system(f'cp -r {clustering_dir} {output_dir}/0/')

# %%
inp_root = Path('data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104_Evaluation/RECCSv1/OS1/')
out_root = Path('data/stats/RECCSv1_OS1/')

for network_dir in inp_root.iterdir():
    # Get network id
    network_id = network_dir.name

    for clustering_dir in network_dir.iterdir():
        # Get clustering id
        clustering_id = clustering_dir.name
        if clustering_id in ['0.001', '0.01', '0.1']:
            resolution_id = f'leiden{clustering_id[1:]}'
            clustering_id = 'leiden_cpm_nofiltcm'
        elif clustering_id == 'k10':
            resolution_id = 'k10'
            clustering_id = 'ikc_nofiltcm'
        elif clustering_id == 'mod':
            resolution_id = 'leidenmod'
            clustering_id = 'leiden_mod_nofiltcm'
        elif clustering_id == 'infomap':
            resolution_id = 'infomap'
            clustering_id = 'infomap_nofiltcm'
        else:
            raise ValueError(f'Unknown clustering id: {clustering_id}')

        # Get output directory
        output_dir = out_root / clustering_id / network_id / resolution_id

        # Create output directory
        output_dir.mkdir(parents=True, exist_ok=True)

        # Copy files
        os.system(f'cp -r {clustering_dir} {output_dir}/0/')

# %%
inp_root = Path('data/SBM_FullNetworks/FullNetwork_RECCS_OS1_CM_No_Filtering_104_Evaluation/RECCSv2/OS1/')
out_root = Path('data/stats/RECCSv2_OS1/')

for network_dir in inp_root.iterdir():
    # Get network id
    network_id = network_dir.name

    for clustering_dir in network_dir.iterdir():
        # Get clustering id
        clustering_id = clustering_dir.name
        if clustering_id in ['0.001', '0.01', '0.1']:
            resolution_id = f'leiden{clustering_id[1:]}'
            clustering_id = 'leiden_cpm_nofiltcm'
        elif clustering_id == 'k10':
            resolution_id = 'k10'
            clustering_id = 'ikc_nofiltcm'
        elif clustering_id == 'mod':
            resolution_id = 'leidenmod'
            clustering_id = 'leiden_mod_nofiltcm'
        elif clustering_id == 'infomap':
            resolution_id = 'infomap'
            clustering_id = 'infomap_nofiltcm'
        else:
            raise ValueError(f'Unknown clustering id: {clustering_id}')

        # Get output directory
        output_dir = out_root / clustering_id / network_id / resolution_id

        # Create output directory
        output_dir.mkdir(parents=True, exist_ok=True)

        # Copy files
        os.system(f'cp -r {clustering_dir} {output_dir}/0/')

# %%
inp_root = Path('data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104_Evaluation/RECCSv1/OS1')
out_root = Path('data/stats/RECCSv1_OS1/')

for network_dir in inp_root.iterdir():
    # Get network id
    network_id = network_dir.name

    for clustering_dir in network_dir.iterdir():
        # Get clustering id
        clustering_id = clustering_dir.name
        if clustering_id in ['0.001', '0.01', '0.1']:
            resolution_id = f'leiden{clustering_id[1:]}'
            clustering_id = 'leiden_cpm'
        elif clustering_id == 'k10':
            resolution_id = 'k10'
            clustering_id = 'ikc_cc'
        elif clustering_id == 'mod':
            resolution_id = 'leidenmod'
            clustering_id = 'leiden_mod'
        elif clustering_id == 'infomap':
            resolution_id = 'infomap'
            clustering_id = 'infomap_cc'
        else:
            raise ValueError(f'Unknown clustering id: {clustering_id}')

        # Get output directory
        output_dir = out_root / clustering_id / network_id / resolution_id

        # Create output directory
        output_dir.mkdir(parents=True, exist_ok=True)

        # Copy files
        os.system(f'cp -r {clustering_dir} {output_dir}/0/')

# %%
inp_root = Path('data/SBM_FullNetworks/FullNetwork_RECCS_OS1_NO_CM_CC_104_Evaluation/RECCSv2/OS1')
out_root = Path('data/stats/RECCSv2_OS1/')

for network_dir in inp_root.iterdir():
    # Get network id
    network_id = network_dir.name

    for clustering_dir in network_dir.iterdir():
        # Get clustering id
        clustering_id = clustering_dir.name
        if clustering_id in ['0.001', '0.01', '0.1']:
            resolution_id = f'leiden{clustering_id[1:]}'
            clustering_id = 'leiden_cpm'
        elif clustering_id == 'k10':
            resolution_id = 'k10'
            clustering_id = 'ikc_cc'
        elif clustering_id == 'mod':
            resolution_id = 'leidenmod'
            clustering_id = 'leiden_mod'
        elif clustering_id == 'infomap':
            resolution_id = 'infomap'
            clustering_id = 'infomap_cc'
        else:
            raise ValueError(f'Unknown clustering id: {clustering_id}')

        # Get output directory
        output_dir = out_root / clustering_id / network_id / resolution_id

        # Create output directory
        output_dir.mkdir(parents=True, exist_ok=True)

        # Copy files
        os.system(f'cp -r {clustering_dir} {output_dir}/0/')
